# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
embedding = np.load("data\\processed\\phoenixweather2014t\\features\\landmarks\\01April_2010_Thursday_heute-6694.mp4.npy")
embedding = embedding.reshape(embedding.shape[0], -1, 3)
embedding.shape
# Out:
# (52, 75, 3)

# %%
embedding
# Out:
# array([[[ 7.5573802e-01,  8.2724243e-01,  3.8365692e-07],
#         [ 7.3452342e-01,  7.9695308e-01, -2.7216870e-02],
#         [ 7.0539516e-01,  7.7847171e-01, -4.6441816e-02],
#         ...,
#         [ 4.6439058e-01,  1.7055646e+00,  8.8046205e-01],
#         [ 6.6151953e-01,  1.7666240e+00,  8.4260203e-02],
#         [ 4.9727508e-01,  1.7872083e+00,  5.7059413e-01]],
#
#        [[ 7.6186746e-01,  8.1867784e-01,  2.8835774e-07],
#         [ 7.5593889e-01,  7.9153836e-01, -2.8669845e-02],
#         [ 7.3731184e-01,  7.6663041e-01, -4.9556013e-02],
#         ...,
#         [ 4.7729030e-01,  1.7132794e+00,  8.8912159e-01],
#         [ 6.8733174e-01,  1.7958856e+00,  1.0016079e-01],
#         [ 5.1258612e-01,  1.7941762e+00,  6.2174398e-01]],
#
#        [[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         ...,
# ...

# %%
first = embedding[0]
xs, ys, zs = first[42:, 0], first[42:, 1], first[42:, 2]
# Plot the landmarks as a scatter plot
ax = plt.figure().add_subplot(projection='3d')
ax.scatter(xs, ys, zs)
plt.title("Plot")
plt.gca().invert_xaxis()  # IMPORTANT: match image coordinates
plt.show()
